# %% [markdown]
# # Benchmarking Julia on a PDE: the Kuramoto-Sivashinksy equation
#
# ## The benchmark algorithm: KS-CNAB2
#
# The Kuramoto-Sivashinsky (KS) equation is a nonlinear time-evolving partial differential equation (PDE) on a 1d spatial domain.
#
# \begin{equation*}
# u_t = -u u_{x} - u_{xx} - u_{xxxx}
# \end{equation*}
#
# where $x$ is space, $t$ is time, and subscripts indicate differentiation. We assume a spatial domain $x \in [0, L_x]$ with periodic boundary conditions.
#
# The KS-CNAB2 benchmark algorithm is a simple numerical integration scheme for the KS equation that uses Fourier expansion in space, collocation calculation of the nonlinear term $u u_x$, and finite-differencing in time, specifically 2nd-order Crank-Nicolson Adams-Bashforth (CNAB2) timestepping. Mathematical details of KS-CNAB2 algorithm are provided [below](## Mathematics of the CNAB2 algorithm).
#
# As PDE solvers go, this one is super-simple, about twenty lines of code, and so comparable in scale to the Fibonnaci, pi-sum, etc. benchmarks at https://julialang.org/benchmarks/.
# However this benchmark is a little different from those in that the dominant cost of the algorithm should be the fast Fourier transforms (FFTs), which in all languages are performed with calls to the same external C library, [FFTW](http://fftw.org/). So what I'm testing here is the overhead each language imposes over FFTW for things like function calls, index bounds checking, allocation of temporary arrays, and pointer dereferencing.
#
# This benchmark is meant as a preliminary investigation towards using Julia for classic high-performance computations (HPC) for PDEs from engineering and physics.

# %% [markdown]
# ## Results:
#
# ### Execution time versus simulation size

# %%
using Plots
gr()
d = readdlm("ks-benchmark/cputime.asc")
Nx = d[:,1]
plot( Nx, d[:,7], label="Python", marker=:circ, color="magenta", 
      yscale=:log10, xscale=:log10,xlim=(10,1e07),ylim=(1e-03,1e02))
plot!(Nx, d[:,5], label="Matlab", marker=:circ, color="green")
plot!(Nx, d[:,9], label="Julia naive", marker=:circ, color="orange")
plot!(Nx, d[:,10], label="Julia in-place", marker=:circ, color="yellow")
plot!(Nx, d[:,3], label="C", marker=:circ, color="cyan")
plot!(Nx, d[:,4], label="C++", marker=:circ, color="blue")
plot!(Nx, d[:,11], label="Julia unrolled", marker=:circ, color="red")
plot!(Nx, d[:,2], label="Fortran", marker=:none, color="black")
plot!(Nx, 1e-05*Nx .* log10.(Nx), label="Nx log Nx", xlabel="Nx", ylabel="cpu time", 
linestyle=:dash, color="black", title="execution time, Kuramoto-Sivashinky simulation")
plot!(Nx, 1.9e-05*Nx, label="Nx", linestyle=:dot, color="black")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 55.1181,360.63 592.126,360.63 592.126,27.5591 55.1181,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="55" y="27" width="538" height="334"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.1181,355.634 55.1181,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   144.619,355.634 144.619,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   234.121,355.634 234.121,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   323.622,355.634 323.622,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   413.123,355.634 413.123,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   502.625,355.634 502.625,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,355.634 592.126,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,360.63 584.071,360.63
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,294.016 584.071,294.016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,227.402 584.071,227.402
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,160.787 584.071,160.787
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,94.1732 584.071,94.1732
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,27.5591 584.071,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 592.126,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   144.619,360.63 144.619,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   234.121,360.63 234.121,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   323.622,360.63 323.622,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   413.123,360.63 413.123,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   502.625,360.63 502.625,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,360.63 592.126,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 63.1732,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,294.016 63.1732,294.016
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,227.402 63.1732,227.402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,160.787 63.1732,160.787
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,94.1732 63.1732,94.1732
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,27.5591 63.1732,27.5591
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 45.8514, 379.382)" x="45.8514" y="379.382">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 59.0307, 372.529)" x="59.0307" y="372.529">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 135.353, 379.382)" x="135.353" y="379.382">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 148.532, 372.529)" x="148.532" y="372.529">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 224.854, 379.382)" x="224.854" y="379.382">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 238.033, 372.529)" x="238.033" y="372.529">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 314.355, 379.382)" x="314.355" y="379.382">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 327.535, 372.529)" x="327.535" y="372.529">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 403.857, 379.382)" x="403.857" y="379.382">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 417.036, 372.529)" x="417.036" y="372.529">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 493.358, 379.382)" x="493.358" y="379.382">10</text>
# </g>
# <g clip-path="url(#clip0

# %% [markdown]
# **Comments:**
#
# **Julia unrolled and Fortran results are practically identical.** Look closely for the black line (Fortran) passing through red dots (Julia unrolled).
#
# **Expectation of $N_x \log N_X$ scaling**. Execution time for this algorithm should ideally be dominated by the $N_x \log N_x$ cost of the FFTs. In the above plot, all the codes do appear to scale as $N_x \log N_x$ at large $N_x$ with different prefactors. However it's hard to understand why there would be different prefactors for the FFT cost when all they're all calls to the same FFTW C library. I would expect costs associated with language differences (array access, etc.) to be linear in $N_x$.
#
# **Different Julia implementation:** I wrote three different Julia codes using three different levels of Julia knowledge.
#
#    * **Julia naive** is a straight translation of a Matlab code, all vectorized and paying no attention to allocation of temporary arrays inside the time-stepping loop.
#
#    * **Julia in-place** eliminates temporaries and allocations by using in-place FFTs and julia-0.6's loop fusion capability.
#
#    * **Julia unrolled** uses in-place FFTs and unrolls all the vector time-stepping operations into explicit for loops.
#
# **Who beats whom?** Julia naive beats Python and Matlab (by factors of 1.55 and 1.16), Julia in-place is close to C and  C++ (factor of 1.06), and Julia unrolled is close to  Fortran (factor of 1.03). Execution times of Julia in-place, Julia unrolled, C++, and Fortran are all pretty close, about a 20% spread. The benchmarks were averaged over thousands of runs for $N_x = 32$ scaling down to 8 runs for $N_x = 2^{17}$; even so the timing averages varied a few percent.
#
# **CPU, OS, and compiler:** All benchmarks were run single-threaded on a six-core Intel Core i7-3960X CPU @ 3.30GHz with 64 GB memory running openSUSE Leap 42.2. C and C++ were compiled with clang 3.8.0, Fortran with gfortran 4.8.3, Julia was julia-0.7-DEV, and all used optimization ``-O3``. For more details see [benchmark-data/cputime.asc](benchmark-data/cputime.asc).

# %%
plot!(xlim=(1e02,2e05), ylim=(0,40), yscale=:linear, xscale=:linear)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 55.1181,360.63 592.126,360.63 592.126,27.5591 55.1181,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="55" y="27" width="538" height="334"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   189.169,355.634 189.169,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   323.488,355.634 323.488,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   457.807,355.634 457.807,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,355.634 592.126,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,360.63 584.071,360.63
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,277.362 584.071,277.362
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,194.094 584.071,194.094
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,110.827 584.071,110.827
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,27.5591 584.071,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 592.126,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   189.169,360.63 189.169,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   323.488,360.63 323.488,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   457.807,360.63 457.807,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,360.63 592.126,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 63.1732,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,277.362 63.1732,277.362
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,194.094 63.1732,194.094
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,110.827 63.1732,110.827
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,27.5591 63.1732,27.5591
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 189.169, 374.43)" x="189.169" y="374.43">50000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 323.488, 374.43)" x="323.488" y="374.43">100000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 457.807, 374.43)" x="457.807" y="374.43">150000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 374.43)" x="592.126" y="374.43">200000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 365.13)" x="49.1181" y="365.13">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 281.862)" x="49.1181" y="281.862">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 198.594)" x="49.1181" y="198.594">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 115.327)" x="49.1181" y="115.327">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 32.0591)" x="49.1181" y="32.0591">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 323.622, 18)" x="323.622" y="18">execution time, Kuramoto-Sivashinky simulation</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 323.622, 397.6)" x="323.622" y="397.6">Nx</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 194.094)" x="14.4" y="194.094">cpu time</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#ff00ff; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.9354,359.947 55.0214,359.897 55.1933,359.814 55.5372,359.672 56.2249,359.298 57.6003,358.615 60.3512,357.183 65.8529,354.46 76.8563,347.64 98.8632,330.57
#   142.877,307.588 230.904,230.732 406.959,63.3642
#   "/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="55.1933" cy="359.814" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#ff00ff; stroke:none; fill-opacity:1" cx="55.1933" cy="359.814" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="55.5372" cy="359.672" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#ff00ff; stroke:none; fill-opacity:1" cx="55.5372" cy="359.672" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="56.2249" cy="359.298" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#ff00ff; stroke:none; fill-opacity:1" cx="56.2249" cy="359.298" r="3"/>
# <circle clip-path="url(#clip02)" style="

# %% [markdown]
# Timings for the last datapoint, $N_x = 2^{17} = 131072$. Cputime is in seconds. The last column shows cputime normalized so that C = 1.
#
# language | cputime | ratio to C
# ---------|---------|------
# Python         | 35.7 | 2.45
# Matlab         | 26.8 | 1.83
# Julia naive    | 23.1 | 1.58
# Julia in-place | 15.5 | 1.06
# C              | 14.6 | 1.00
# C++            | 14.4 | 0.99
# Julia unrolled | 13.6 | 0.93
# Fortran        | 13.0 | 0.90

# %% [markdown]
# ### execution time versus lines of code

# %%
d = readdlm("ks-benchmark/linecount.asc")
Nx = d[:,1]
plot([d[1,2]], [d[1,1]],  label="Python", marker=:circ, color="magenta")
plot!([d[2,2]], [d[2,1]], label="Matlab", marker=:circ, color="green" )
plot!([d[3,2]], [d[3,1]], label="Julia naive", marker=:circ, color="orange")
plot!([d[4,2]], [d[4,1]], label="Julia in-place", marker=:circ, color="yellow")
plot!([d[5,2]], [d[5,1]], label="Julia unrolled", marker=:circ, color="red")
plot!([d[6,2]], [d[6,1]], label="Fortran", marker=:circ, color="black")
plot!([d[7,2]], [d[7,1]], label="C++", marker=:circ, color="blue")
plot!([d[8,2]], [d[8,1]], label="C", marker=:circ, color="cyan")
plot!(xlabel="lines of code", ylabel="cpu time, seconds", xlim=(0,80), ylim=(0,40))
plot!(title="Kuramoto-Sivashinky simulation: cputime versus lines of code")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 55.1181,360.63 592.126,360.63 592.126,27.5591 55.1181,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="55" y="27" width="538" height="334"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.1181,355.634 55.1181,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   189.37,355.634 189.37,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   323.622,355.634 323.622,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   457.874,355.634 457.874,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,355.634 592.126,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,360.63 584.071,360.63
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,277.362 584.071,277.362
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,194.094 584.071,194.094
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,110.827 584.071,110.827
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,27.5591 584.071,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 592.126,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   189.37,360.63 189.37,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   323.622,360.63 323.622,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   457.874,360.63 457.874,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,360.63 592.126,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 63.1732,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,277.362 63.1732,277.362
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,194.094 63.1732,194.094
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,110.827 63.1732,110.827
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,27.5591 63.1732,27.5591
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.1181, 374.43)" x="55.1181" y="374.43">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 189.37, 374.43)" x="189.37" y="374.43">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 323.622, 374.43)" x="323.622" y="374.43">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 457.874, 374.43)" x="457.874" y="374.43">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 374.43)" x="592.126" y="374.43">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 365.13)" x="49.1181" y="365.13">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 281.862)" x="49.1181" y="281.862">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 198.594)" x="49.1181" y="198.594">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 115.327)" x="49.1181" y="115.327">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 32.0591)" x="49.1181" y="32.0591">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 323.622, 18)" x="323.622" y="18">Kuramoto-Sivashinky simulation: cputime versus lines of code</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 323.622, 397.6)" x="323.622" y="397.6">lines of code</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 194.094)" x="14.4" y="194.094">cpu time, seconds</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="182.657" cy="63.3642" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#ff00ff; stroke:none; fill-opacity:1" cx="182.657" cy="63.3642" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="196.083" cy="137.472" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#008000; stroke:none; fill-opacity:1" cx="196.083" cy="137.472" r="3"/>
# <circle clip-path="ur

# %% [markdown]
# **Comments**
#
# Julia in-place and Julia unrolled clearly hit the sweet spot of low execution time and low line count.
#
# I included the ``KS module`` definition in the linecount for the Fortran ``ksintegrate`` function, since the module serves as part of the function interface.

# %% [markdown]
# ### Ratio of execution speed to linecount
#
# Define execution speed as 1/cputime, so speed/linecount = 1/(cputime\*linecount). Normalize so C = 1.

# %%
c = d[8,2]*d[8,1] # normalization constant making C = 1
plot([1], [c/(d[1,2]*d[1,1])],  label="Python", marker=:circ, color="magenta")
plot!([2], [c/(d[2,2]*d[2,1])], label="Matlab", marker=:circ, color="green" )
plot!([3], [c/(d[3,2]*d[3,1])], label="Julia naive", marker=:circ, color="orange")
plot!([4], [c/(d[4,2]*d[4,1])], label="Julia in-place", marker=:circ, color="yellow")
plot!([5], [c/(d[5,2]*d[5,1])], label="Julia unrolled", marker=:circ, color="red")
plot!([6], [c/(d[6,2]*d[6,1])], label="Fortran", marker=:circ, color="black")
plot!([7], [c/(d[7,2]*d[7,1])], label="C++", marker=:circ, color="blue")
plot!([8], [c/(d[8,2]*d[8,1])], label="C", marker=:circ, color="cyan")
plot!(xlabel="language", ylabel="speed/linecount (C++ = 1)",ylim=(0,3), xlim=(0,10))
plot!(title="Kuramoto-Sivashinky simulation: speed/linecount ratio")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 55.1181,360.63 592.126,360.63 592.126,27.5591 55.1181,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="55" y="27" width="538" height="334"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.1181,355.634 55.1181,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   162.52,355.634 162.52,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   269.921,355.634 269.921,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   377.323,355.634 377.323,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   484.724,355.634 484.724,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,355.634 592.126,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,360.63 584.071,360.63
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,305.118 584.071,305.118
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,249.606 584.071,249.606
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,194.094 584.071,194.094
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,138.583 584.071,138.583
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,83.0709 584.071,83.0709
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.1732,27.5591 584.071,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 592.126,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   162.52,360.63 162.52,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.921,360.63 269.921,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   377.323,360.63 377.323,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   484.724,360.63 484.724,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,360.63 592.126,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 63.1732,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,305.118 63.1732,305.118
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,249.606 63.1732,249.606
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,194.094 63.1732,194.094
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,138.583 63.1732,138.583
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,83.0709 63.1732,83.0709
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,27.5591 63.1732,27.5591
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.1181, 374.43)" x="55.1181" y="374.43">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 162.52, 374.43)" x="162.52" y="374.43">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.921, 374.43)" x="269.921" y="374.43">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 377.323, 374.43)" x="377.323" y="374.43">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 484.724, 374.43)" x="484.724" y="374.43">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 374.43)" x="592.126" y="374.43">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 365.13)" x="49.1181" y="365.13">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 309.618)" x="49.1181" y="309.618">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 254.106)" x="49.1181" y="254.106">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 198.594)" x="49.1181" y="198.594">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 143.083)" x="49.1181" y="143.083">2.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="

# %% [markdown]
# **Comments**
#
# Julia in-place is the winner in the speed/linecount metric.

# %% [markdown]
# ## Mathematics of the CNAB2 algorithm
#
# Start from the Kuramoto-Sivashinsky equation $[0,L]$ with periodic boundary conditions
#
# \begin{equation*}
# u_t = - u_{xx} - u_{xxxx} - u u_{x}
# \end{equation*}
#
# on the domain $[0,L_x]$ with periodic boundary conditions and initial condition $u(x,0) = u_0(x)$. We will use a finite Fourier expansion to discretize space and finite-differencing to discretize time, specifically the 2nd-order rank-Nicolson/Adams-Bashforth (CNAB2) timestepping formula. CNAB2 is low-order but straightforward to describe and easy to implement for this simple benchmark.
#
# Write the KS equation as
#
# \begin{equation*}
# u_t = Lu + N(u)
# \end{equation*}
#
# where $Lu = - u_{xx} - u_{xxxx}$ is the linear terms and $N(u) = -u u_{x}$ is the nonlinear term. In practice we'll calculate the $N(u)$ in the equivalent form $N(u) = - 1/2 \, d/dx \, u^2$.
#
# Discretize time by letting $u^n(x) = u(x, n\Delta t)$ for some small $\Delta t$. The CNAB2 timestepping forumale approximates  $u_t = Lu + N(u)$ at time $t = (n+1/2) \, dt$ as
#
# \begin{equation*}
# \frac{u^{n+1} - u^n}{\Delta t} = L\left(u^{n+1} + u^n\right) + \frac{3}{2} N(u^n) - \frac{1}{2} N(u^{n-1})
# \end{equation*}
#
#
# Put the unknown future $u^{n+1}$'s on the left-hand side of the equation and the present $u^{n}$ and past $u^{n+1}$ on the right.
#
# \begin{equation*}
# \left(I  - \frac{\Delta t}{2} L \right) u^{n+1} = \left(I  + \frac{\Delta t}{2}L \right) u^{n} + \frac{3 \Delta t}{2} N(u^n) - \frac{\Delta t}{2} N(u^{n-1})
# \end{equation*}
# Note that the linear operator $L$ applies to the unknown $u^{n+1}$ on the LHS, but that the nonlinear operator $N$ applies only to the knowns $u^n$ and $u^{n-1}$ on the RHS. This is an *implicit* treatment of the linear terms, which keeps the algorithm stable for large time steps, and an *explicit* treament of the nonlinear term, which makes the timestepping equation linear in the unknown $u^{n+1}$.
#
# Now we discretize space with a finite Fourier expansion, so that $u$ now represents a vector of Fourier coefficients and $L$ turns into matrix (and a diagonal matrix, since Fourier modes are eigenfunctions of the linear operator). Let matrix $A = (I  - \Delta t/2 \; L)$, matrix $B =  (I  + \Delta t/2 \; L)$, and let vector $N^n$ be the Fourier transform of a collocation calculation of $N(u^n)$. That is, $N^n$ is the Fourier transform of $- u u_x = - 1/2 \, d/dx \, u^2$ calculated at $N_x$ uniformly spaced gridpoints on the domain $[0, L_x]$.
#
# With the spatial discretization, then the CNAB2 timestepping formula becomes
#
# \begin{equation*}
# A \, u^{n+1} = B \, u^n + \frac{3 \Delta t}{2} N^n -  \frac{\Delta t}{2}N^{n-1}
# \end{equation*}
#
# This is a simple $Ax=b$ linear algebra problem whose iteration approximates the time-evolution of the Kuramoto-Sivashinksy PDE.

# %% [markdown]
# ## Julia implementations of CNAB2 algorithm
#
# ### Julia naive
#
# The naive Julia code is pretty much a line-by-line translation of the same thing in Matlab, about 30 lines of code excluding comments and whitespace. Here's a slight modification of the benchmarked algorithm which saves and plots $u(x,t)$ data.

# %%
function ksintegrateNaive(u, Lx, dt, Nt, nsave)
    
    Nx = length(u)                  # number of gridpoints
    x = collect(0:(Nx-1)/Nx)*Lx
    kx = vcat(0:Nx/2-1, 0, -Nx/2+1:-1)  # integer wavenumbers: exp(2*pi*kx*x/L)
    alpha = 2*pi*kx/Lx              # real wavenumbers:    exp(alpha*x)
    D = 1im*alpha;                  # D = d/dx operator in Fourier space
    L = alpha.^2 - alpha.^4         # linear operator -D^2 - D^4 in Fourier space
    G = -0.5*D                      # -1/2 D operator in Fourier space
    
    Nsave = div(Nt, nsave)+1        # number of saved time steps, including t=0
    t = (0:Nsave)*(dt*nsave)        # t timesteps
    U = zeros(Nsave, Nx)            # matrix of u(xⱼ, tᵢ) values
    U[1,:] = u                      # assign initial condition to U
    s = 2                           # counter for saved data
    
    # Express PDE as u_t = Lu + N(u), L is linear part, N nonlinear part.
    # Then Crank-Nicolson Adams-Bashforth discretization is 
    # 
    # (I - dt/2 L) u^{n+1} = (I + dt/2 L) u^n + 3dt/2 N^n - dt/2 N^{n-1}
    #
    # let A = (I - dt/2 L) 
    #     B = (I + dt/2 L), then the CNAB timestep formula is
    # 
    # u^{n+1} = A^{-1} (B u^n + 3dt/2 N^n - dt/2 N^{n-1}) 

    # convenience variables
    dt2  = dt/2
    dt32 = 3*dt/2;
    A_inv = (ones(Nx) - dt2*L).^(-1)
    B     =  ones(Nx) + dt2*L

    Nn  = G.*fft(u.*u) # -u u_x (spectral), notation Nn = N^n     = N(u(n dt))
    Nn1 = copy(Nn)     #                   notation Nn1 = N^{n-1} = N(u((n-1) dt))
    u  = fft(u)        # transform u to spectral

    # timestepping loop
    for n = 1:Nt
        Nn1 = copy(Nn)                 # shift nonlinear term in time: N^{n-1} <- N^n
        Nn  = G.*fft(real(ifft(u)).^2) # compute Nn = -u u_x

        u = A_inv .* (B .* u + dt32*Nn - dt2*Nn1)
        
        if mod(n, nsave) == 0
            U[s,:] = real(ifft(u))
            s += 1            
        end
    end

    t,U
end
# Out:
# ksintegrateNaive (generic function with 1 method)

# %% [markdown]
# ### Run the Julia code and plot results

# %%
Lx = 64*pi
Nx = 1024
dt = 1/16
nsave = 8
Nt = 3200

x = Lx*(0:Nx-1)/Nx
u = cos.(x) + 0.1*sin.(x/8) + 0.01*cos.((2*pi/Lx)*x);
t,U = ksintegrateNaive(u, Lx, dt, Nt, nsave)

heatmap(x,t,U, xlim=(x[1], x[end]), ylim=(t[1], t[end]), xlabel="x", ylabel="t", 
title="Kuramoto-Sivashinsky dynamics", fillcolor=:bluesreds)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 55.1181,360.63 592.126,360.63 592.126,27.5591 55.1181,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="55" y="27" width="478" height="334"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.1181,355.634 55.1181,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   173.856,355.634 173.856,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   292.594,355.634 292.594,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   411.332,355.634 411.332,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   530.07,355.634 530.07,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,360.63 524.971,360.63
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,277.57 524.971,277.57
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,194.51 524.971,194.51
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,111.45 524.971,111.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,28.3897 524.971,28.3897
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 532.126,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   173.856,360.63 173.856,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.594,360.63 292.594,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   411.332,360.63 411.332,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   530.07,360.63 530.07,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 62.2732,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,277.57 62.2732,277.57
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,194.51 62.2732,194.51
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,111.45 62.2732,111.45
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,28.3897 62.2732,28.3897
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.1181, 374.43)" x="55.1181" y="374.43">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 173.856, 374.43)" x="173.856" y="374.43">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 292.594, 374.43)" x="292.594" y="374.43">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 411.332, 374.43)" x="411.332" y="374.43">150</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 530.07, 374.43)" x="530.07" y="374.43">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 365.13)" x="49.1181" y="365.13">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 282.07)" x="49.1181" y="282.07">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 199.01)" x="49.1181" y="199.01">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 115.95)" x="49.1181" y="115.95">150</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 32.8897)" x="49.1181" y="32.8897">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 293.622, 18)" x="293.622" y="18">Kuramoto-Sivashinsky dynamics</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 293.622, 397.6)" x="293.622" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 194.094)" x="14.4" y="194.094">t</text>
# </g>
# <g clip-path="url(#clip02)">
# <image width="477" height="334" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAd0AAAFOCAYAAADDz8eDAAAgAElEQVR4nOy92a5lWZYlNFaz29Pe
# 1lp3N7Mw94jISDIrlUUBKokEVIIv4jt4RfwBn4CExAOIKsgSlanKiIzO3cPD3Zrb39Pss5vV8TDn
# Wnsf8+CNx7jSkV0zu/c0e681mzHGHEsBgCgl/uG///fZ//x//E++DSHc3bX3f/ev/qL7P//v/+cK
# f/7689efv/789eevP3/9+ev/ly/xv/yP/0PwwwBAQFUlsrMTlM+foddz/PqXO9zdDtjvHZz1EFIg
# yyTyXCAvJJQSEEJAAIAABACpBPJcIs8lykqinmkslhqrtYbbbHD4wx8xXN9guL2D3e4RvIdezFC+
# fIGzv/vX+O1vWnz7dYOb6wHGeBSFxJOnBU7PcpycZlisMtS1Ql5IaCUQrIE3Fr7vYfcN7OMG/e0d
# hqtrHL77Hq4

# %% [markdown]
# ### Julia in-place
#
# The naive Julia code (straight Matlab translation) is slightly slower than Matlab. Can tune the Julia code by
#   * doing FFTs in-place
#   * removing temporary vectors in time-stepping loop
#
# These very simple improvements get the Julia performance slightly faster than C++ within 10% of Fortran.

# %%
function ksintegrateInplace(u, Lx, dt, Nt, nsave);
    u = (1+0im)*u                       # force u to be complex
    Nx = length(u)                      # number of gridpoints
    kx = vcat(0:Nx/2-1, 0:0, -Nx/2+1:-1)# integer wavenumbers: exp(2*pi*kx*x/L)
    alpha = 2*pi*kx/Lx                  # real wavenumbers:    exp(alpha*x)
    D = 1im*alpha                       # spectral D = d/dx operator 
    L = alpha.^2 - alpha.^4             # spectral L = -D^2 - D^4 operator
    G = -0.5*D                          # spectral -1/2 D operator, to eval -u u_x = 1/2 d/dx u^2

    Nsave = div(Nt, nsave)+1        # number of saved time steps, including t=0
    t = (0:Nsave)*(dt*nsave)        # t timesteps
    U = zeros(Nsave, Nx)            # matrix of u(xⱼ, tᵢ) values
    U[1,:] = u                      # assign initial condition to U
    s = 2                           # counter for saved data
    
    # convenience variables
    dt2  = dt/2
    dt32 = 3*dt/2
    A_inv = (ones(Nx) - dt2*L).^(-1)
    B     =  ones(Nx) + dt2*L
    
    # compute in-place FFTW plans
    FFT! = plan_fft!(u, flags=FFTW.ESTIMATE)
    IFFT! = plan_ifft!(u, flags=FFTW.ESTIMATE)

    # compute nonlinear term Nn == -u u_x 
    Nn  = G.*fft(u.^2);    # Nn == -1/2 d/dx (u^2) = -u u_x
    Nn1 = copy(Nn);        # Nn1 = Nn at first time step
    FFT!*u;
    
    # timestepping loop
    for n = 1:Nt

        Nn1 .= Nn       # shift nonlinear term in time
        Nn .= u         # put u into Nn in prep for comp of nonlinear term
        
        IFFT!*Nn;       # transform Nn to gridpt values, in place
        Nn .= Nn.*Nn;   # collocation calculation of u^2
        FFT!*Nn;        # transform Nn back to spectral coeffs, in place

        Nn .= G.*Nn;    # compute Nn == -1/2 d/dx (u^2) = -u u_x

        # loop fusion! Julia translates the folling line of code to a single for loop. 
        u .= A_inv .* (B .* u .+ dt32.*Nn .- dt2.*Nn1); 
        
        if mod(n, nsave) == 0
            U[s,:] = real(ifft(u))
            s += 1            
        end
    end
   
    t,U
end
# Out:
# ksintegrateInplace (generic function with 1 method)

# %%
t,U = ksintegrateInplace(u, Lx, dt, Nt, nsave)
heatmap(x,t,U, xlim=(x[1], x[end]), ylim=(t[1], t[end]), xlabel="x", ylabel="t", 
title="Kuramoto-Sivashinsky dynamics", fillcolor=:bluesreds)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 55.1181,360.63 592.126,360.63 592.126,27.5591 55.1181,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="55" y="27" width="478" height="334"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.1181,355.634 55.1181,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   173.856,355.634 173.856,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   292.594,355.634 292.594,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   411.332,355.634 411.332,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   530.07,355.634 530.07,32.5551
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,360.63 524.971,360.63
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,277.57 524.971,277.57
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,194.51 524.971,194.51
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,111.45 524.971,111.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.2732,28.3897 524.971,28.3897
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 532.126,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   173.856,360.63 173.856,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.594,360.63 292.594,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   411.332,360.63 411.332,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   530.07,360.63 530.07,355.634
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 55.1181,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,360.63 62.2732,360.63
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,277.57 62.2732,277.57
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,194.51 62.2732,194.51
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,111.45 62.2732,111.45
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.1181,28.3897 62.2732,28.3897
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.1181, 374.43)" x="55.1181" y="374.43">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 173.856, 374.43)" x="173.856" y="374.43">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 292.594, 374.43)" x="292.594" y="374.43">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 411.332, 374.43)" x="411.332" y="374.43">150</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 530.07, 374.43)" x="530.07" y="374.43">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 365.13)" x="49.1181" y="365.13">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 282.07)" x="49.1181" y="282.07">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 199.01)" x="49.1181" y="199.01">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 115.95)" x="49.1181" y="115.95">150</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 49.1181, 32.8897)" x="49.1181" y="32.8897">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 293.622, 18)" x="293.622" y="18">Kuramoto-Sivashinsky dynamics</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 293.622, 397.6)" x="293.622" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 194.094)" x="14.4" y="194.094">t</text>
# </g>
# <g clip-path="url(#clip02)">
# <image width="477" height="334" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAd0AAAFOCAYAAADDz8eDAAAgAElEQVR4nOy9165l2ZUlNpbZ9thr
# w6aJYGSSbJaqulCtloQGVGpBkD5Pr/oVAQL0oIduoQR0E11k0WYymRnu2uP22WY5Pcy51t4nknrU
# Gy9wEDci7j1mmWnGGHNOAMC/LyT++vXXr79+/fXrr19//frr1/+/X+J//9/+1+CHAYCAqkpkF2co
# nz9Dr+f4za/2uL8bcDg4OOshpECWSeS5QF5IKCUghIAAAAEIAFIJ5LlEnkuUlUQ901gsNVZrDbfd
# 4vinP2O4ucVwdw+7OyB4D72YoXz5Ahf/+O/wu9+2+PaPDW5vBhjjURQST54WOL/IcXaeYbHKUNcK
# eSGhlUCwBt5Y+L6HPTSwmy36u3sMH29w/O57uOYIkWkUT66x+PlPsf43f4/f/MHgn/7jI/ZbA6UF
# VusM108LPHt

# %% [markdown]
# ### Julia unrolled
#
# The [Julia unrolled code](codes/ksintegrateUnrolled.jl) uses in-place FFTs and unrolls several time-stepping vector operations into for loops.

# %% [markdown]
# ## Benchmark codes, all languages
#
# Here are the benchmark codes, which include both the integration algorithm and a driver program to run and time the algorithm at a given $N_x$. I haven't bothered to automate the running of the benchmark codes or the production of the benchmark data files. I run them manually as follows, from within the ``codes`` directory.
#
# **Python:** [ksbenchmark.py](codes/ksbenchmark.py) From an interactive python shell run
#
# ```
# Python 2.7.13 (default, Mar 22 2017, 12:31:17) [GCC]
# IPython 3.2.2 -- An enhanced Interactive Python.
# In [1]: execfile("ksbenchmark.py")
#
# In [2]: ksbenchmark(512)
# ```
#
# **Matlab:** [ksbenchmark.m](codes/ksbenchmark.m) From a Matlab prompt
#
# ```
# >> ksbenchmark(512)
# ```
#
#
# **Julia:** [ksbenchmark.jl](codes/ksbenchmark.jl) At the Julia REPL run
#
# ```
# julia> include("ksbenchmark.jl")
# julia> ksbenchmark(512, ksintegrateNaive)
# ```
#
# etc. for ``ksintegrateInplace`` and ``ksintegrateUnrolled``. Or, better, use Julia's benchmarking tools, which compute a more reliable timing that the simple average-of-Nruns tic-toc approach used in my ``ksbenchmark`` function.
#
# ```
# julia> using BenchmarkTools
# julia> @benchmark ksintegrateNaive(ksinitconds(512)...)
# ```
#
# **C:** [ksbenchmark.c](codes/ksbenchmark.c) At Unix prompt
#
# ```
# bash$ clang -O3 -o ksbenchmark-c ksbenchmark.c -lfftw3 -lm
# bash$ ksbenchmark-c 512
# ```
#
# **C++:** [ksbenchmark.cpp](codes/ksbenchmark.cpp) At Unix prompt
#
# ```
# bash$ clang -O3 -o ksbenchmark-c++ -lfftw3 -lm
# bash$ ksbenchmark-c++ 512
# ```
#
# **Fortran:** [ksbenchmark.f90](codes/ksbenchmark.f90) Edit the file to set $N_x$, then at Unix prompt
#
# ```
# bash$ gfortran -O3 -o ksbenchmark-f90 -lfftw3
# bash$ ksbenchmark-f90
# ```
#
# Details about compilers versions and optimization flags are listed in the [cputime.asc](benchmark-data/cputime.asc) data file.

# %% [markdown]
# ## Room for improvement
#
#   * Automate the build and benchmarking process
#   * Implement more highly-tuned/sophisticated approaches
#       * Numba and Dedalus codes for Python
#       * ``DifferentialEquations.jl + ApproxFun.jl`` code for Julia
#       * real-to-complex versions wherever possible
#       * multithreaded versions
#   * Analysis of the overhead costs.
#   * Do something similar with a 2d or 3d PDE and distributed-memory computations.
#
#
# ## Acknowledgements
#
# Thanks to
#
#   * Mahtab Lak, University of New Hampshire Mathematics. Her Ph.D. Minor Project in Applied Math formed the basis for this work.
#   * Ashley Willis, University of Sheffield, wrote the Fortran 90 code.
#   * David Sanders, Universidad Nacional Autónoma de México, for encouraging me to put this notebook together.
#   * Chris Rackauckas, University of California Irvine, for Julia performance tips.
#   * Sheehan Olver, University of Sydney, and Chris Rackauckas, for Julia Discourse discussions on strategies for implementing HPC PDE codes in Julia.
#   * traktofon@github for fixing the Fortran code in numerous ways
#
# John F. Gibson,
# Dept. Mathematics and Statistics,
# University of New Hampshire
